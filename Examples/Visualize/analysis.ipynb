# %% [markdown]
# # Python Visulization of SpringSaLaD Outputs
#
# This notebook demonstrates different ways visualize the CSV outputs generate by SpringSaLaD.

# %%
#Import necessary functions and data
from SpringSaLaDpy.Visualization import *
from SpringSaLaDpy.data_locator import data_file_finder
from SpringSaLaDpy.display_info import *
from SpringSaLaDpy.Project_reader import Describe_input_file
from SpringSaLaDpy.MolDraw.MolDraw_exec import display_molecules

# %%
#Create the relative path to your desired SIMULATIONS or FOLDER directory
#search_directory = os.path.join('..', '..', 'Examples', 'GUI_results', 'Nephrin-Nck-NWasp', 'Final_version_test_SIMULATIONS', 'Simulation0_SIM_SIMULATIONS')
search_directory = os.path.join('..', 'Simulate', 'modified_input_FOLDER')

#Get a description of the input file in that directory

#add flag: skip_links
Describe_input_file(search_directory, links=False, reactions=True, kinetics=True)
# Out:
# Moleclues:
#
# MOLECULE: "R" (Initial Count: 6)
# This molecule has 3 site types: R (2 possible states: State0, State1), L, Anchor
#
# It consists of 4 connected sites:
# Type R: 2 intracellular sites (Site 0, Site 2)
# Type Anchor: 1 membrane (Site 1)
# Type L: 1 intracellular (Site 3)
# ------------------------------------------------------------------------------------------------------------
#
# MOLECULE: "Adapter" (Initial Count: 2)
# This molecule has 2 site types: A, L
#
# It consists of 3 connected sites:
# Type A: 2 intracellular sites (Site 0, Site 2)
# Type L: 1 intracellular (Site 1)
# ------------------------------------------------------------------------------------------------------------
#
# ************************************************************************************************************
#
# Reaction Rules
#
# State Transition Reactions: 1
# A site of type R in a R molecule can change its state from State0 to State1 at a rate of 0.0 s-1 provided that it is bound to site A of a molecule Adapter
#
# Allosteric Reactions: 1
# Site 0 of molecule R can change its state from State0 to State1 at a rate of 0.0 s-1 provided that Site 2 of the same molecule is in state State0
#
# Biomolecular Binding Reactions: 1
# Site R of molecule R (in any state) can bind to site A of Adapter
# 	On rate: 5 uM-1.s-1, off rate: 20 s-1

# %%
display_molecules(search_directory)
# Out:
# R:
# Adapter:

# %%
#Choose a file in the data folder by giving a search term (some part of the file name) or the full file name
path = data_file_finder(search_directory, ['data'], search_term='BondCounts', file_name=None)
file_info(path, list_neighbors=True)

# %%
#Plot the selected data over time
Plotter.plot(path)

#Get a list of columns and their respective indicies
column_info(path)

# %%
#Select only the columns you want to see graphed
Plotter.plot(path, [1, 2, 5])

# %%
#Change the data file
path = data_file_finder(search_directory, ['data'], 'MoleculeCounts')
column_info(path)
Plotter.plot(path, [3,6,9])

# %%
#Show the average Z position of each molecule
Average_z_pos.plot(search_directory, indicies=[], verbose=True, legend_right=True, list_options=True, mode='mol', fill=True)
# Out:
# Molecules:
# 0: R
# 1: Adapter
#
# List of indicies:
# [0, 1]

# %%
#Shorten legend with Verbose=False and set list_options=False so only the graph is displayed
Average_z_pos.plot(search_directory, indicies=[0,1], verbose=False, legend_right=False, list_options=False, mode='mol', fill=True)

# %%
#View radius of gyration and bonds per molecule distribution (shows last data point by default)
Spatial_Analysis.plot(search_directory, times=[])
# Out:
# System:  modified_input_FOLDER
# Calculating Cluster Density ...
# Progress : [****************************************] 100%
# Execution time : 0.1959 secs

# %%
#Select a specific point in time
Spatial_Analysis.plot(search_directory, [0.002, 0.004])
# Out:
# System:  modified_input_FOLDER
# Calculating Cluster Density ...
# Progress : [****************************************] 100%
# Execution time : 0.1949 secs

# %%
#View cluster size distribution histogram at a particular point in time with or without bins
Histogram.plot(search_directory, [], 0.01)
#Histogram.plot(search_directory, [], 0.01)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 #View cluster size distribution histogram at a particular point in time with or without bins
# ----> 2 Histogram.plot(search_directory, [], 0.01)
#       3 #Histogram.plot(search_directory, [], 0.01)
#
# File c:\Users\cpero\AppData\Local\Programs\Python\Python310\lib\site-packages\SpringSaLaDpy\Visualization\Histogram.py:18, in plot(search_directory, bins, time)
#      14 dt_data = float(split_file[0][4][9:])
#      16 search_term = 'Size_Freq_Fotm'
# ---> 18 time, fotm_file = find_nearest_time(search_directory, path_list, time, dt_data, search_term)
#      20 outpath = os.path.normpath(fotm_file)
#      21 outpath = os.path.join(*outpath.split(os.sep)[:-5])
#
# File c:\Users\cpero\AppData\Local\Programs\Python\Python310\lib\site-packages\SpringSaLaDpy\time_rounder.py:12, in find_nearest_time(search_directory, path_list, time, dt_data, search_term)
#       9 else:
#      10     time = round(time - (time % dt_data), 6)
# ---> 12 decimals = os.path.split(data_file_finder(search_directory, path_list, search_term))[1].split('_')[2].split('.')[1]
#      14 time = format(float(time), f'.{len(decimals)}f')
#      15 file = data_file_finder(search_directory, path_list, time)
#
# File c:\Users\cpero\AppData\Local\Programs\Python\Python310\lib\site-packages\SpringSaLaDpy\data_locator.py:36, in data_file_finder(search_directory, path_list, search_term, file_name, run)
#      34     result = find_files(lower_search_directory, f'Run{run}')
#      35 else:
# ---> 36     result = find_files(lower_search_directory, search_term)
#      37 return result
#
# File c:\Users\cpero\AppData\Local\Programs\Python\Python310\lib\site-packages\SpringSaLaDpy\data_locator.py:15, in find_files(search_directory, search_term)
#      13 def find_files(search_directory, search_term):
#      14     match = None
# ---> 15     for filename in os.listdir(search_directory):
#      16         if search_term in filename:
#      17             match = os.path.join(search_directory, filename)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '..\\Simulate\\modified_input_FOLDER\\data\\Cluster_stat\\Histograms\\Size_Freq_Fotm\\MEAN_Run'

# %%
Cluster_comp.plot(search_directory, 0.02)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 Cluster_comp.plot(search_directory, 0.02)
#
# File c:\Users\cpero\AppData\Local\Programs\Python\Python310\lib\site-packages\SpringSaLaDpy\Visualization\Cluster_comp.py:17, in plot(search_directory, time, specialClusters, width, alpha)
#      13 dt_data = float(split_file[0][4][9:])
#      15 search_term = 'Size_Comp_Freq'
# ---> 17 time, comp_file = find_nearest_time(search_directory, path_list, time, dt_data, search_term)
#      19 df = pd.read_csv(comp_file)
#      20 df = df.rename({'Size':'Clusters'}, axis = 1)
#
# File c:\Users\cpero\AppData\Local\Programs\Python\Python310\lib\site-packages\SpringSaLaDpy\time_rounder.py:12, in find_nearest_time(search_directory, path_list, time, dt_data, search_term)
#       9 else:
#      10     time = round(time - (time % dt_data), 6)
# ---> 12 decimals = os.path.split(data_file_finder(search_directory, path_list, search_term))[1].split('_')[2].split('.')[1]
#      14 time = format(float(time), f'.{len(decimals)}f')
#      15 file = data_file_finder(search_directory, path_list, time)
#
# File c:\Users\cpero\AppData\Local\Programs\Python\Python310\lib\site-packages\SpringSaLaDpy\data_locator.py:36, in data_file_finder(search_directory, path_list, search_term, file_name, run)
#      34     result = find_files(lower_search_directory, f'Run{run}')
#      35 else:
# ---> 36     result = find_files(lower_search_directory, search_term)
#      37 return result
#
# File c:\Users\cpero\AppData\Local\Programs\Python\Python310\lib\site-packages\SpringSaLaDpy\data_locator.py:15, in find_files(search_directory, search_term)
#      13 def find_files(search_directory, search_term):
#      14     match = None
# ---> 15     for filename in os.listdir(search_directory):
#      16         if search_term in filename:
#      17             match = os.path.join(search_directory, filename)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '..\\Simulate\\modified_input_FOLDER\\data\\Cluster_stat\\Histograms\\Size_Comp_Freq\\MEAN_Run'

# %%
Bound_fraction.plot(search_directory, [0.01])
# Out:
# Class : CrossLinkIndex
# System : ..\Simulate\modified_input_FOLDER\modified_input.txt
# Could not locate SiteIDs.csv across 0 runs
# Could not locate SiteIDs.csv across 0 runs
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 Bound_fraction.plot(search_directory, [0.01])
#
# File c:\Users\cpero\AppData\Local\Programs\Python\Python310\lib\site-packages\SpringSaLaDpy\Visualization\Bound_fraction.py:29, in plot(search_directory, times, hist)
#      24 print(CLI)
#      25 #d = cl.mapSiteToMolecule()
#      26 #rif = ReadInputFile(txtfile)
#      27 #print(rif.getReactiveSites())
#      28 #print(len(cl.getActiveSiteIDs()))
# ---> 29 CLI.getSI(vf)
#      30 CLI.getSI_stat()
#      31 CLI.plot_SI_stat(color='k', fs=16, xticks=None, yticks=None, hist=hist, title_str=title_str)
#
# File c:\Users\cpero\AppData\Local\Programs\Python\Python310\lib\site-packages\SpringSaLaDpy\Visualization\ClusterCrossLinking.py:159, in CrossLinkIndex.getSI(self, viewerfile)
#     157 CS_list = [] # list of clusters
#     158 SI_list = []
# --> 159 msm = self.mapSiteToMolecule()
#     160 completeTrajectory = False
#     161 tps, index_pairs = self.getSteadyStateFrameIndices(viewerfile)
#
# File c:\Users\cpero\AppData\Local\Programs\Python\Python310\lib\site-packages\SpringSaLaDpy\Visualization\ClusterCrossLinking.py:106, in CrossLinkIndex.mapSiteToMolecule(self)
#     104 molIDs, siteIDs = {}, {}
#     105 for mol in molName:
# --> 106     molIDs.update(self.getMolIds(mIDfile, mol))
#     107     siteIDs.update(self.getSiteIds(sIDfile, mol))
#     108 spmIDs = {} # sites per molecule
#
# File c:\Users\cpero\AppData\Local\Programs\Python\Python310\lib\site-packages\SpringSaLaDpy\Visualization\ClusterCrossLinking.py:40, in CrossLinkIndex.getMolIds(molfile, molName)
#      38 molDict = {}
#      39 mIds = []
# ---> 40 with open(molfile, 'r') as tmpfile:
#      41     for line in tmpfile:
#      42         line = line.strip().split(',')
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType

# %%
#data_selection options are 'rg' (cluster radius of gyration), 'cs' (cluster size or number of molecules in a cluster), and 'mr' (maximum cluster radius relative to cluster COM)
#indicies selects maximuim (0), average (1), or both in the plot below. It's both by default
#Warning: computationally intensive for larger simulations
Spatial_Analysis.time_course(search_directory, data_selection='rg', indicies=[0,1], size_threshold=1)

# %%
Spatial_Analysis.time_course(search_directory, data_selection='cs', indicies=[0,1], size_threshold=1)

# %%
Spatial_Analysis.time_course(search_directory, data_selection='mr', indicies=[0,1], size_threshold=1)
